# %% [markdown]
# # NTDS demo 6: web APIs & data analysis with pandas
# [Michaël Defferrard](http://deff.ch), *PhD student*, [EPFL](http://epfl.ch) [LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## 1 Web API
#
# We already used the Twitter web API, albeit through a nice Python wrapper library. This time, we'll talk to an API directly.

# %% [markdown]
# ### 1.1 API doc
#
# The first step is always to look at the API documentation. Two questions to answer: i) how to construct the uniform resource locator (URL), and ii) how to interpret the returned data. For this tutorial and the third assignment: <https://freemusicarchive.org/api>. (Some of you might have referred to the [Twitter API doc](https://developer.twitter.com/en/docs) for the first assignment.)
#
# **Start simple**. Send an HTTP GET request with your web browser to the following uniform resource locator (URL): <https://freemusicarchive.org/recent.json>.

# %% [markdown]
# ### 1.2 API calls
#
# A well-designed [HTTP](https://en.wikipedia.org/wiki/Http) library for Python is [request](http://python-requests.org).

# %%
import requests

# %% [markdown]
# Send an HTTP GET request, as our browser did above, and receive a `response` from the web server.

# %%
URL = 'https://freemusicarchive.org/recent.json'
response = requests.get(URL)

# %% [markdown]
# If the GET request worked, the server answers with a "200 OK", the standard response for successful HTTP requests. The request may fail and e.g. return the infamous "404 Not Found" error.

# %%
print(response.status_code)
print(requests.get('https://www.epfl.ch/do_not_exist').status_code)
# Out:
# 200
# 404

# %% [markdown]
# ### 1.3 Exercise

# %% [markdown]
# First, as often, we need an API key for certain operations. Add the following to your `credentials.ini` file.
# ```
# [freemusicarchive]
# api_key = MY-KEY
# ```

# %%
# Read the confidential api key.
import configparser
import os
credentials = configparser.ConfigParser()
credentials.read(os.path.join('../Assignments', 'credentials.ini'))
api_key = credentials.get('freemusicarchive', 'api_key')

# %% [markdown]
# Find the name of the artist which has an ID of 58.

# %%
ARTIST_ID = 58

dataset = 'artists'
f = 'json'
url = 'https://freemusicarchive.org/api/get/%s.%s?api_key=%s&artist_id=%d' % (dataset, f, api_key, ARTIST_ID)

print(url)
requests.get(url).content
# Out:
# https://freemusicarchive.org/api/get/artists.json?api_key=MN9IV2ZG9CJERJYQ&artist_id=58
# b'{"title":"Free Music Archive - Artists","message":"","errors":[],"total":"1","total_pages":1,"page":1,"limit":20,"dataset":[{"artist_id":"58","artist_handle":"Andy_Hayleck","artist_url":"http:\\/\\/freemusicarchive.org\\/music\\/Andy_Hayleck\\/","artist_name":"Andy Hayleck","artist_bio":"<p><span style=\\"font-family:Arial, Helvetica, sans-serif;\\">Electro-acoustic composer and instrumentalist Andy Hayleck                        is a quiet storm of the Baltimore experimental music scene,                        a virtuoso of sound whose range of highly developed projects                        and approaches is dizzying - spanning everything from jazz                        and ska guitar to musique concrete and the invention of                        new instruments and electro-acoustic systems. Hayleck \\"enjoy[s]                        collaborating with animate and inanimate objects.\\"                        In the animate realm, he has worked with free improvisors,                        drum\'n\'bass djs, pop and ska groups, experimental musical                        instrument builders and artists. In the inanimate realm                        he has worked with vibrating metal systems of one, two and                        three dimensions, air, water, and electricity.He currently                        plays in the ensemble Aerotrain (a group that performs compositions                        on instruments built by Neil Feather) and Heavy Things,                        as well as solo (primarily with his own<\\/span><span style=\\"font-family:Arial, Helvetica, sans-serif;\\">,                        highly original amplified gong\\/wire and live electronics). (-via the <a href=\\"http:\\/\\/www.highzero.org\\/2003_site\\/the_musicians\\/index.htm\\">High Zero Festival of Experimental Improvised Music<\\/a> website)<br \\/><\\/span><\\/p>","artist_members":null,"artist_website":"http:\\/\\/www.ehserecords.com\\/ehse006.html","artist_wikipedia_page":null,"artist_donation_url":"http:\\/\\/ehserecords.com\\/ehse006.html","artist_contact":"Andy Hayleck","artist_active_year_begin":null,"artist_active_year_end":null,"artist_related_projects":null,"artist_associated_labels":null,"artist_comments":"0","artist_favorites":"1","artist_date_created":"11\\/26\\/2008 12:52:35 AM","artist_flattr_name":null,"artist_paypal_name":null,"artist_latitude":"39.290384800000","artist_longitude":"-76.612189300000","artist_image_file":"https:\\/\\/freemusicarchive.org\\/file\\/images\\/artists\\/Andy_Hayleck_-_2009113014422121.jpg","artist_location":"Baltimore, MD","tags":["andy hayleck"],"artist_images":[{"image_id":"609","image_file":"https:\\/\\/freemusicarchive.org\\/file\\/images\\/artists\\/Andy_Hayleck_-_2009113014422121.jpg","image_title":"artists Image","image_caption":null,"image_copyright":null,"image_source":null}]}]}'

# %% [markdown]
# ## 2 JSON
#
# The goal of an HTTP GET request is to get data. The returned data might be HTML (as you see when you browse the web), XML, JSON, etc. Most web APIs nowadays return data formated as [JSON](https://en.wikipedia.org/wiki/JSON). As JSON data objects consist of key-value pairs and lists, the format is well modeled by Python dictionaries and lists.

# %%
data = response.json()

# %% [markdown]
# The above call to `json()` interprets the returned data as being JSON and constructs Python dictionary and list objects out of it. In this case the top-level object is a dictionary, with some keys.

# %%
print(type(data))
print(data.keys())
# Out:
# <class 'dict'>
# dict_keys(['content', 'aFeeds', 'title', 'page_title', 'page_cache_key', 'oNav', 'nav_genres', 'nav_curators', 'bAuth', 'bManage', 'sSearch', 'aMailForm', 'aTracks'])

# %% [markdown]
# Let's look at the value of the "title" key.

# %%
data['title']
# Out:
# 'Free Music Archive'

# %% [markdown]
# Exploring the returned data is a good way to learn about the API. Let's get to what we were looking for, a list of recently added tracks.

# %%
print(type(data['aTracks']))
print(data['aTracks'][0].keys())
# Out:
# <class 'list'>
# dict_keys(['track_id', 'album_id', 'artist_id', 'agreement_id', 'track_title', 'track_handle', 'language_code', 'track_image_file', 'track_duration', 'track_number', 'track_disc_number', 'track_explicit', 'track_explicit_notes', 'track_upload_confirmed', 'track_file', 'track_file_type', 'track_bit_rate', 'track_sample_rate', 'track_encoding_software', 'track_original_id3', 'track_copyright_c', 'track_copyright_p', 'track_composer', 'track_lyricist', 'track_publisher', 'track_instrumental', 'track_information', 'track_notes', 'track_status_encoding', 'track_status', 'track_date_recorded', 'track_date_created', 'track_date_modified', 'track_date_deleted', 'track_date_published', 'track_comments', 'track_favorites', 'track_listens', 'track_downloads', 'track_interest', 'track_deleted', 'artist_name', 'album_title', 'license_id', 'license_parent_id', 'license_title', 'license_url', 'license_image_file', 'license_image_file_large', 'language_title', 'artist_published', 'artist_url', 'album_url', 'track_url', 'track_file_url', 'track_listen_url', 'track_user_favorite'])

# %%
for track in data['aTracks'][:5]:
    print(track['track_title'])
# Out:
# Cool It
# Bliss
# Brain Dance
# Rhythm
# Movemet

# %% [markdown]
# ### 2.1 Exercise

# %% [markdown]
# Construct a list of the names of the 16 top-level genres. No need to call the API again, everything is in the above collected JSON data.

# %%
genres = []
for item in data['nav_genres']:
    genres.append(item['genre_title'])

assert type(genres) is list
print(genres)
# Out:
# ['Blues', 'Classical', 'Country', 'Electronic', 'Experimental', 'Folk', 'Hip-Hop', 'Instrumental', 'International', 'Jazz', 'Novelty', 'Old-Time / Historic', 'Pop', 'Rock', 'Soul-RnB', 'Spoken']

# %% [markdown]
# ## 3 Pandas: data analysis in Python
#
# While it might be sufficient to keep the data as lists and dictionaries, we often prefer to see data in a tabular format for analysis. A tabular format allows to make operations on the rows and columns, e.g. by taking a sum over prices. At a large scale, tabular data is stored in a [database](https://en.wikipedia.org/wiki/Database) (think the list of clients of a compagny). At a small scale, you probably used it in the form of an Excel spreadsheet. In Python, [pandas](https://pandas.pydata.org) is the most used data analysis tool. You can think of it as a *programmable spreadsheet*.

# %% [markdown]
# Let's first create a simple table, called a `DataFrame` in pandas' language. We can initialize the table with e.g. a Python list or a NumPy array. As our running example, let's say we want to do some accounting for our family and define the following schema: each row is a member of the family, the first column represents the revenue and the second the expenses. Sure enough, we can create a NumPy array.

# %%
import numpy as np

accounts = np.array([[10, 20], [30, 30], [40, 20]])
print(accounts)
# Out:
# [[10 20]
#  [30 30]
#  [40 20]]

# %% [markdown]
# But that's not very user friendly. Who's the second line already? Enter pandas.

# %%
import pandas as pd

accounts = pd.DataFrame(accounts)
accounts
# Out:
#     0   1
# 0  10  20
# 1  30  30
# 2  40  20

# %% [markdown]
# But this is not much more useful than our NumPy array. Let's e.g. name the rows and columns.

# %%
accounts.columns = ['revenues', 'expenditures']
accounts.index = ['John', 'Mary', 'Alison']
accounts.index.name = 'given name'
accounts
# Out:
#             revenues  expenditures
# given name
# John              10            20
# Mary              30            30
# Alison            40            20

# %% [markdown]
# Now if I want to know how much Alison spent this month, I don't have to remember that Alison is the third row and that the expenditures are the second column. I can query:

# %%
accounts.at['Alison', 'expenditures']
# Out:
# 20

# %% [markdown]
# We may want to compute the revenue of the entire familiy (note the similarity with the way you would do it in a spreadsheet):

# %%
accounts['revenues'].sum()
# Out:
# 80

# %% [markdown]
# Or the balance of each member:

# %%
accounts['balance'] = accounts['revenues'] - accounts['expenditures']
accounts
# Out:
#             revenues  expenditures  balance
# given name
# John              10            20      -10
# Mary              30            30        0
# Alison            40            20       20

# %% [markdown]
# Another quite useful feature is selection:

# %%
accounts[accounts['balance'] < 0]
# Out:
#             revenues  expenditures  balance
# given name
# John              10            20      -10

# %% [markdown]
# Or sorting:

# %%
accounts.sort_values('expenditures')
# Out:
#             revenues  expenditures  balance
# given name
# John              10            20      -10
# Alison            40            20       20
# Mary              30            30        0

# %% [markdown]
# Now it's time to save our data for archival, or to open it up in another tool.

# %%
accounts.to_csv(os.path.join('..', 'data', 'family_accounts.csv'))

# %%
# !cat ../data/family_accounts.csv
# Windows: !type ..\data\family_accounts.csv
# Out:
# given name,revenues,expenditures,balance
# John,10,20,-10
# Mary,30,30,0
# Alison,40,20,20

# %% [markdown]
# These are very basic operations to give you an idea of what pandas is. More info in the [docs](http://pandas.pydata.org/pandas-docs/stable/). That library will certainly be useful for your projects.

# %% [markdown]
# ### 3.1 Exercise
#
# Using pandas and the above data (i.e. `data['aTracks']`), find how many tracks each artist published.

# %%
data['aTracks']
# Out:
# [{'agreement_id': '29387',
#   'album_id': '24714',
#   'album_title': 'UNTIL NOW',
#   'album_url': 'http://freemusicarchive.org/music/Nctrnm/Until_Now/',
#   'artist_id': '21533',
#   'artist_name': 'Nctrnm',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Nctrnm/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '123',
#   'license_image_file': 'http://i.creativecommons.org/l/by/4.0/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by.png',
#   'license_parent_id': '2',
#   'license_title': 'Attribution',
#   'license_url': 'http://creativecommons.org/licenses/by/4.0/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': 'Matthew McGilvery',
#   'track_copyright_c': 'Matthew McGilvery',
#   'track_copyright_p': 'Matthew McGilvery',
#   'track_date_created': '11/05/2017 04:11:25 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/06/2017 02:58:02 AM',
#   'track_date_published': '11/06/2017 02:38:39 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '0',
#   'track_duration': '03:40',
#   'track_encoding_software': None,
#   'track_explicit': 'Radio-Safe',
#   'track_explicit_notes': None,
#   'track_favorites': '1',
#   'track_file': 'music/ccCommunity/Nctrnm/UNTIL_NOW/Nctrnm_-_04_-_Cool_It.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/8c381e280f5e6c088a8bd320c0f321d86228f689',
#   'track_handle': 'NctrnmCoolIt121Bm',
#   'track_id': '166285',
#   'track_image_file': 'https://freemusicarchive.org/file/images/tracks/Nctrnm_-_04_-_Cool_It_-_2017110624810810.jpg',
#   'track_information': '<p>cool it; nctrnm: November 3 2017;F Major; 121bpm</p>',
#   'track_instrumental': '1',
#   'track_interest': '21',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/8c381e280f5e6c088a8bd320c0f321d86228f689',
#   'track_listens': '20',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '4',
#   'track_original_id3': '{"album":"Until Now","artist":"Nctrnm","attached or linked picture":{"description":"","encoding":0,"file":"\\/tmp\\/tmpWFh2Pi.jpg","mime":"image\\/jpeg","type":0,"type_title":"Other"},"beats per minute":"121","composer":"Matthew McGilvery","encoder settings":"LAME 64bits version 3.99.5 (http:\\/\\/lame.sf.net)","genre":"Electronic","group":"Nctrnm","part of set":{"number":"1","total":"1"},"recording time":"2017","title":"Cool It","track number":{"number":"4","total":"7"},"user comment":{"language":"eng","text":"b minor\\r\\n"}}',
#   'track_publisher': 'Matthew McGilvery',
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Cool It',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Nctrnm/Until_Now/NctrnmCoolIt121Bm',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29386',
#   'album_id': '24713',
#   'album_title': 'Brownian Motion',
#   'album_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/',
#   'artist_id': '25289',
#   'artist_name': 'The 303',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/The_303/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '16',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/3.0/us/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-Noncommercial-Share Alike 3.0 United States',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/3.0/us/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 06:35:51 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 06:42:54 PM',
#   'track_date_published': '11/05/2017 06:39:35 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '51',
#   'track_duration': '01:59',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/no_curator/The_303/Brownian_Motion/The_303_-_06_-_Bliss.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/d88e6a05f56184eabf54ee9a90d65eedabe6ce29',
#   'track_handle': '06_303_-_Bliss',
#   'track_id': '166284',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/The_Tleilaxu_Music_Machine_-_2009113015734804.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '755',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/d88e6a05f56184eabf54ee9a90d65eedabe6ce29',
#   'track_listens': '704',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '6',
#   'track_original_id3': '{"album":" Brownian Motion","artist":"303","genre":"Electronic","recording time":"2014","title":"Bliss","track number":{"number":"6"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Bliss',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/06_303_-_Bliss',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29386',
#   'album_id': '24713',
#   'album_title': 'Brownian Motion',
#   'album_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/',
#   'artist_id': '25289',
#   'artist_name': 'The 303',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/The_303/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '16',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/3.0/us/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-Noncommercial-Share Alike 3.0 United States',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/3.0/us/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 06:35:51 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 06:42:53 PM',
#   'track_date_published': '11/05/2017 06:39:35 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '27',
#   'track_duration': '09:49',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/no_curator/The_303/Brownian_Motion/The_303_-_05_-_Brain_Dance.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/b40585433b4a44b2e49cf6ac047283c55c1bf10f',
#   'track_handle': '05_303_-_Brain_Dance',
#   'track_id': '166283',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/The_Tleilaxu_Music_Machine_-_2009113015734804.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '364',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/b40585433b4a44b2e49cf6ac047283c55c1bf10f',
#   'track_listens': '337',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '5',
#   'track_original_id3': '{"album":" Brownian Motion","artist":"303","genre":"Electronic","recording time":"2014","title":"Brain Dance","track number":{"number":"5"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Brain Dance',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/05_303_-_Brain_Dance',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29386',
#   'album_id': '24713',
#   'album_title': 'Brownian Motion',
#   'album_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/',
#   'artist_id': '25289',
#   'artist_name': 'The 303',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/The_303/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '16',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/3.0/us/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-Noncommercial-Share Alike 3.0 United States',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/3.0/us/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 06:35:50 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 06:42:49 PM',
#   'track_date_published': '11/05/2017 06:39:34 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '26',
#   'track_duration': '04:22',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/no_curator/The_303/Brownian_Motion/The_303_-_04_-_Rhythm.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/7d9359f0aea0d9fac96e70a8299b09e122178dd7',
#   'track_handle': '04_303_-_Rhythm',
#   'track_id': '166282',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/The_Tleilaxu_Music_Machine_-_2009113015734804.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '233',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/7d9359f0aea0d9fac96e70a8299b09e122178dd7',
#   'track_listens': '207',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '4',
#   'track_original_id3': '{"album":" Brownian Motion","artist":"303","genre":"Electronic","recording time":"2014","title":"Rhythm","track number":{"number":"4"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Rhythm',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/04_303_-_Rhythm',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29386',
#   'album_id': '24713',
#   'album_title': 'Brownian Motion',
#   'album_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/',
#   'artist_id': '25289',
#   'artist_name': 'The 303',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/The_303/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '16',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/3.0/us/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-Noncommercial-Share Alike 3.0 United States',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/3.0/us/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 06:35:49 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 06:42:44 PM',
#   'track_date_published': '11/05/2017 06:39:34 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '33',
#   'track_duration': '08:52',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/no_curator/The_303/Brownian_Motion/The_303_-_03_-_Movemet.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/12e54ef8c8a18b4ca7d7f5400d128aee87cf6f7b',
#   'track_handle': '03_303_-_Movement',
#   'track_id': '166281',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/The_Tleilaxu_Music_Machine_-_2009113015734804.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '212',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/12e54ef8c8a18b4ca7d7f5400d128aee87cf6f7b',
#   'track_listens': '179',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '3',
#   'track_original_id3': '{"album":" Brownian Motion","artist":"303","genre":"Electronic","recording time":"2014","title":"Movemet","track number":{"number":"3"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Movemet',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/03_303_-_Movement',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29386',
#   'album_id': '24713',
#   'album_title': 'Brownian Motion',
#   'album_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/',
#   'artist_id': '25289',
#   'artist_name': 'The 303',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/The_303/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '16',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/3.0/us/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-Noncommercial-Share Alike 3.0 United States',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/3.0/us/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 06:35:49 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 06:42:45 PM',
#   'track_date_published': '11/05/2017 06:39:33 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '9',
#   'track_duration': '05:12',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/no_curator/The_303/Brownian_Motion/The_303_-_02_-_Glide.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/5c82cf0ef3ce5533f46c026344899a1f9dea8fd1',
#   'track_handle': '02_303_-_Glide',
#   'track_id': '166280',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/The_Tleilaxu_Music_Machine_-_2009113015734804.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '153',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/5c82cf0ef3ce5533f46c026344899a1f9dea8fd1',
#   'track_listens': '144',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '2',
#   'track_original_id3': '{"album":" Brownian Motion","artist":"303","genre":"Electronic","recording time":"2014","title":"Glide","track number":{"number":"2"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Glide',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/02_303_-_Glide',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29386',
#   'album_id': '24713',
#   'album_title': 'Brownian Motion',
#   'album_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/',
#   'artist_id': '25289',
#   'artist_name': 'The 303',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/The_303/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '16',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/3.0/us/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-Noncommercial-Share Alike 3.0 United States',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/3.0/us/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 06:35:48 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 06:42:35 PM',
#   'track_date_published': '11/05/2017 06:39:33 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '55',
#   'track_duration': '08:40',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/no_curator/The_303/Brownian_Motion/The_303_-_01_-_Meditation.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/28d8d70c5392fbf39516752f8fd238230ab4568f',
#   'track_handle': '01_303_-_Meditation',
#   'track_id': '166279',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/The_Tleilaxu_Music_Machine_-_2009113015734804.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '411',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/28d8d70c5392fbf39516752f8fd238230ab4568f',
#   'track_listens': '356',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '1',
#   'track_original_id3': '{"album":" Brownian Motion","artist":"303","genre":"Electronic","recording time":"2014","title":"Meditation","track number":{"number":"1"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Meditation',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/The_303/Brownian_Motion/01_303_-_Meditation',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29383',
#   'album_id': '24710',
#   'album_title': 'NIOBE',
#   'album_url': 'http://freemusicarchive.org/music/Dee_Yan-Key/NIOBE/',
#   'artist_id': '24811',
#   'artist_name': 'Dee Yan-Key',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Dee_Yan-Key/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '124',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-NonCommercial-ShareAlike',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#   'track_bit_rate': '255172',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 09:54:30 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:46:21 AM',
#   'track_date_published': '11/05/2017 11:46:21 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '121',
#   'track_duration': '13:46',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/ccCommunity/Dee_Yan-Key/NIOBE/Dee_Yan-Key_-_02_-_the_last_daughter.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/33502607e7e2c526a9041d1186621b25e8124710',
#   'track_handle': '02--Dee_Yan-Key-the_last_daughter',
#   'track_id': '166262',
#   'track_image_file': 'https://freemusicarchive.org/file/images/tracks/Track_-_2017110594842551',
#   'track_information': None,
#   'track_instrumental': '1',
#   'track_interest': '1471',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/33502607e7e2c526a9041d1186621b25e8124710',
#   'track_listens': '1350',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '2',
#   'track_original_id3': '{"album":"NIOBE","artist":"Dee Yan-Key","attached or linked picture":{"description":"","encoding":0,"file":"\\/tmp\\/tmpgifVuq.jpg","mime":"image\\/jpeg","type":0,"type_title":"Other"},"composer":"Dee Yan-Key","encoder":"Jamendo:http:\\/\\/www.jamendo.com| LAME","genre":"","recording time":"2016","title":"the last daughter","track number":{"number":"2"},"user comment":{"language":"eng","text":"http:\\/\\/www.jamendo.com cc_standard"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'the last daughter',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Dee_Yan-Key/NIOBE/02--Dee_Yan-Key-the_last_daughter',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29383',
#   'album_id': '24710',
#   'album_title': 'NIOBE',
#   'album_url': 'http://freemusicarchive.org/music/Dee_Yan-Key/NIOBE/',
#   'artist_id': '24811',
#   'artist_name': 'Dee Yan-Key',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Dee_Yan-Key/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '124',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-sa.png',
#   'license_parent_id': '5',
#   'license_title': 'Attribution-NonCommercial-ShareAlike',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#   'track_bit_rate': '255547',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 09:54:29 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:46:20 AM',
#   'track_date_published': '11/05/2017 11:46:20 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '64',
#   'track_duration': '20:45',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '2',
#   'track_file': 'music/ccCommunity/Dee_Yan-Key/NIOBE/Dee_Yan-Key_-_01_-_a_mothers_mourning.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/e626b3cb8a0b15195e1908eac548b82bcbd88b03',
#   'track_handle': 'a_mothers_mourning',
#   'track_id': '166261',
#   'track_image_file': 'https://freemusicarchive.org/file/images/tracks/Track_-_2017110594702255',
#   'track_information': None,
#   'track_instrumental': '1',
#   'track_interest': '489',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/e626b3cb8a0b15195e1908eac548b82bcbd88b03',
#   'track_listens': '423',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '1',
#   'track_original_id3': '{"album":"NIOBE","artist":"Dee Yan-Key","attached or linked picture":{"description":"","encoding":0,"file":"\\/tmp\\/tmpt3tY40.jpg","mime":"image\\/jpeg","type":0,"type_title":"Other"},"composer":"Dee Yan-Key","encoder":"Jamendo:http:\\/\\/www.jamendo.com| LAME","genre":"calm","recording time":"2016","title":"a mother\\u00b4s mourning","track number":{"number":"1"},"user comment":{"language":"eng","text":"http:\\/\\/www.jamendo.com cc_standard"}}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'a mother´s mourning',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Dee_Yan-Key/NIOBE/a_mothers_mourning',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:05 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:32:02 AM',
#   'track_date_published': '11/05/2017 11:32:02 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '28',
#   'track_duration': '03:58',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_09_-_9_Girl_Confused.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/c613ded4a4536dfd54653b2098955c9900b46881',
#   'track_handle': '9_Now_That_Shes_Gone',
#   'track_id': '166271',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '550',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/c613ded4a4536dfd54653b2098955c9900b46881',
#   'track_listens': '522',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '9',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"9. Girl Confused","user comment":[{"language":"eng","text":" 000005E2 000006FC 000035AD 00004715 0002F2E5 0002F53E 00006A76 00006A76 000275B1 00026E24"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': "Now That She's Gone",
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/9_Now_That_Shes_Gone',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:04 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:32:01 AM',
#   'track_date_published': '11/05/2017 11:32:01 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '15',
#   'track_duration': '03:01',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_08_-_Worlds_Greatest_Dancer.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/b6b2f8627862259f5a72cc6ab359c1b88deeb698',
#   'track_handle': 'Worlds_Greatest_Dancer',
#   'track_id': '166270',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '209',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/b6b2f8627862259f5a72cc6ab359c1b88deeb698',
#   'track_listens': '194',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '8',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"8. Worlds Greatest Dancer","user comment":[{"language":"eng","text":" 000004E1 000004C9 00002889 00002152 00001C0F 0001C092 00006A76 00006A76 00024A53 0001DCBC"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': "World's Greatest Dancer",
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/Worlds_Greatest_Dancer',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:04 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 02:05:56 PM',
#   'track_date_published': '11/05/2017 11:32:01 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '34',
#   'track_duration': '03:37',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_07_-_Picture_Perfect_People.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/018e5d5ae9cc40e6f357b711f6f59f5188ae040d',
#   'track_handle': '7_Picture_Perfect_People',
#   'track_id': '166269',
#   'track_image_file': 'https://freemusicarchive.org/file/images/albums/PLANET_WARDO_-_PLANET_WARDO_-_20171105112323344.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '343',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/018e5d5ae9cc40e6f357b711f6f59f5188ae040d',
#   'track_listens': '309',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '7',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"7. Picture Perfect People","user comment":[{"language":"eng","text":" 00000506 0000056C 00003C56 000022AF 0000D339 00025F58 00006A76 00006A76 00030E0A 0001D2D6"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Picture Perfect People',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/7_Picture_Perfect_People',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:03 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 02:05:37 PM',
#   'track_date_published': '11/05/2017 11:32:00 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '20',
#   'track_duration': '03:47',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_06_-_Like_Magic.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/0aae668305aeda1561b569a79e596ae88bf8bfb6',
#   'track_handle': '6_Like_Magic',
#   'track_id': '166268',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '194',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/0aae668305aeda1561b569a79e596ae88bf8bfb6',
#   'track_listens': '174',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '6',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"6. Like Magic","user comment":[{"language":"eng","text":" 0000055F 000006E4 0000309A 0000E788 0002FCCB 00021E8D 00006A76 00006A76 0000F7A7 00021E24"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Like Magic',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/6_Like_Magic',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:03 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:31:59 AM',
#   'track_date_published': '11/05/2017 11:31:59 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '7',
#   'track_duration': '04:25',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_05_-_5_Judy.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/62434c1eafed61d23109322d5d7467fd708277ff',
#   'track_handle': '5_Judy',
#   'track_id': '166267',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '112',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/62434c1eafed61d23109322d5d7467fd708277ff',
#   'track_listens': '105',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '5',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"5. Judy","user comment":[{"language":"eng","text":" 000003E8 00000464 00004156 0000343D 00033849 00033849 00006A76 00006A76 0001C697 00004787"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Judy',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/5_Judy',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:02 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:31:59 AM',
#   'track_date_published': '11/05/2017 11:31:59 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '14',
#   'track_duration': '04:56',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_04_-_4_On_We_Go.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/a845cfa98ff0bf445cf69c85224c90bf91b24af0',
#   'track_handle': '4_On_We_Go',
#   'track_id': '166266',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '117',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/a845cfa98ff0bf445cf69c85224c90bf91b24af0',
#   'track_listens': '103',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '4',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"4. On We Go","user comment":[{"language":"eng","text":" 00000939 000009BA 000044A9 000034AC 0002D449 0003A40A 00006A76 00006A76 000030AC 000060F0"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'On We Go',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/4_On_We_Go',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:02 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:31:58 AM',
#   'track_date_published': '11/05/2017 11:31:58 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '8',
#   'track_duration': '04:13',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_03_-_3_Sensitivity_in_the_Digital_Age.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/bd1752d4a6a4663166a42808319e843c1e3c2aec',
#   'track_handle': '3_Sensitivity_in_the_Digital_Age',
#   'track_id': '166265',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '66',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/bd1752d4a6a4663166a42808319e843c1e3c2aec',
#   'track_listens': '58',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '3',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"3. Sensitivity in the Digital Age","user comment":[{"language":"eng","text":" 0000060B 0000055D 0000691F 00003954 0002D54E 00002D82 00006A76 00006A76 00028C3E 00032687"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Sensitivity in the Digital Age',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/3_Sensitivity_in_the_Digital_Age',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:01 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:31:58 AM',
#   'track_date_published': '11/05/2017 11:31:58 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '14',
#   'track_duration': '02:51',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_02_-_The_Easy_Life.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/8b63c6b0487bbe555ffcacf7a639daa448a48f2e',
#   'track_handle': 'The_Easy_Life',
#   'track_id': '166264',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '94',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/8b63c6b0487bbe555ffcacf7a639daa448a48f2e',
#   'track_listens': '80',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '2',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"2. The Easy Life","user comment":[{"language":"eng","text":" 00000E7B 000009C1 000073D1 00003E59 0001D9FA 0001369C 00006A76 00006A76 00018CD6 00013CD6"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'The Easy Life',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/The_Easy_Life',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29384',
#   'album_id': '24711',
#   'album_title': 'PLANET WARDO',
#   'album_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/',
#   'artist_id': '22345',
#   'artist_name': 'PLANET WARDO',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Jamie_Ward/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '14',
#   'license_image_file': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly_88.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/downloadonly.png',
#   'license_parent_id': None,
#   'license_title': 'FMA-Limited: Download Only',
#   'license_url': 'http://freemusicarchive.org/FMA_License',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/05/2017 11:01:01 AM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/05/2017 11:31:57 AM',
#   'track_date_published': '11/05/2017 11:31:57 AM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '46',
#   'track_duration': '03:02',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/Oddio_Overplay/PLANET_WARDO/PLANET_WARDO/PLANET_WARDO_-_01_-_Here_We_Are.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/eb978a8e181374a6625850249182869e953b0ecd',
#   'track_handle': 'Here_We_Are_1555',
#   'track_id': '166263',
#   'track_image_file': 'https://freemusicarchive.org/file/images/artists/PLANET_WARDO_-_20171105110121356.jpg',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '523',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/eb978a8e181374a6625850249182869e953b0ecd',
#   'track_listens': '477',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '1',
#   'track_original_id3': '{"encoder":"iTunes 12.6.1.27","title":"1. Here We Are","user comment":[{"language":"eng","text":" 0000069C 00000811 00004F93 0000659D 0000F7C1 0001CAAC 00006A76 00006A76 0001CD39 00020BC6"}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Here We Are',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Jamie_Ward/PLANET_WARDO/Here_We_Are_1555',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29380',
#   'album_id': '24707',
#   'album_title': 'Only One - Single',
#   'album_url': 'http://freemusicarchive.org/music/Fleslit/Only_One_-_Single/',
#   'artist_id': '23208',
#   'artist_name': 'Fleslit',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Fleslit/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '123',
#   'license_image_file': 'http://i.creativecommons.org/l/by/4.0/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by.png',
#   'license_parent_id': '2',
#   'license_title': 'Attribution',
#   'license_url': 'http://creativecommons.org/licenses/by/4.0/',
#   'track_bit_rate': '320000',
#   'track_comments': '0',
#   'track_composer': 'Fleslit',
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/04/2017 04:31:56 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/04/2017 08:32:43 PM',
#   'track_date_published': '11/04/2017 08:32:23 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '241',
#   'track_duration': '03:38',
#   'track_encoding_software': None,
#   'track_explicit': None,
#   'track_explicit_notes': None,
#   'track_favorites': '0',
#   'track_file': 'music/ccCommunity/Fleslit/Only_One_-_Single/Fleslit_-_Only_One.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/9d11501e3db4f22b0a6ae84e3dc281fa56ea747f',
#   'track_handle': 'Only_One_1671',
#   'track_id': '166260',
#   'track_image_file': 'https://freemusicarchive.org/file/images/tracks/Track_-_20171104212213956',
#   'track_information': None,
#   'track_instrumental': '1',
#   'track_interest': '1903',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/9d11501e3db4f22b0a6ae84e3dc281fa56ea747f',
#   'track_listens': '1662',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '0',
#   'track_original_id3': '{"album":"Only One - Single","artist":"Fleslit","attached or linked picture":{"description":"","encoding":0,"file":"\\/tmp\\/tmpy218Qo.jpg","mime":"image\\/jpeg","type":0,"type_title":"Other"},"composer":"Fleslit","encoder":"LAME in FL Studio 12","genre":"Hip Hop\\/Rap","group":"Fleslit","recording time":"2017","title":"Only One"}',
#   'track_publisher': 'Fleslit',
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Only One',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Fleslit/Only_One_-_Single/Only_One_1671',
#   'track_user_favorite': '0'},
#  {'agreement_id': '29379',
#   'album_id': '24706',
#   'album_title': 'Firmament',
#   'album_url': 'http://freemusicarchive.org/music/Ketsa/Firmament/',
#   'artist_id': '6443',
#   'artist_name': 'Ketsa',
#   'artist_published': '1',
#   'artist_url': 'http://freemusicarchive.org/music/Ketsa/',
#   'language_code': None,
#   'language_title': None,
#   'license_id': '126',
#   'license_image_file': 'http://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png',
#   'license_image_file_large': 'http://fma-files.s3.amazonaws.com/resources/img/licenses/by-nc-nd.png',
#   'license_parent_id': '6',
#   'license_title': 'Creative Commons Attribution-NonCommercial-NoDerivatives 4.0',
#   'license_url': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#   'track_bit_rate': '192000',
#   'track_comments': '0',
#   'track_composer': None,
#   'track_copyright_c': None,
#   'track_copyright_p': None,
#   'track_date_created': '11/04/2017 03:31:49 PM',
#   'track_date_deleted': None,
#   'track_date_modified': '11/04/2017 03:46:04 PM',
#   'track_date_published': '11/04/2017 03:46:04 PM',
#   'track_date_recorded': None,
#   'track_deleted': '0',
#   'track_disc_number': '1',
#   'track_downloads': '589',
#   'track_duration': '03:23',
#   'track_encoding_software': None,
#   'track_explicit': '',
#   'track_explicit_notes': None,
#   'track_favorites': '1',
#   'track_file': 'music/blocSonic/Ketsa/Firmament/Ketsa_-_10_-_Wild_Plain.mp3',
#   'track_file_type': None,
#   'track_file_url': 'https://freemusicarchive.org/music/download/df50d02be588ad254bebb736f9ce9fd7beb490a5',
#   'track_handle': 'Wild_Plain_1936',
#   'track_id': '166259',
#   'track_image_file': 'https://freemusicarchive.org/file/images/albums/Ketsa_-_Firmament_-_20171104163644234.JPG',
#   'track_information': None,
#   'track_instrumental': '0',
#   'track_interest': '3574',
#   'track_listen_url': 'https://freemusicarchive.org/music/listen/df50d02be588ad254bebb736f9ce9fd7beb490a5',
#   'track_listens': '2984',
#   'track_lyricist': None,
#   'track_notes': None,
#   'track_number': '10',
#   'track_original_id3': '{"album":"Trix, Clips and Useful Bits","artist":"Ketsa","encoder":"iTunes 12.4.1.6","title":"wild plain stem master","user comment":[{"language":"eng","text":"0 \\/ "}]}',
#   'track_publisher': None,
#   'track_sample_rate': '44100',
#   'track_status': 'published',
#   'track_status_encoding': 'complete',
#   'track_title': 'Wild Plain',
#   'track_upload_confirmed': '1',
#   'track_url': 'http://freemusicarchive.org/music/Ketsa/Firmament/Wild_Plain_1936',
#   'track_user_favorite': '0'}]

# %%
tracks = []
for item in data['aTracks']:
    track = item['track_id']
    artist = item['artist_id']
    tracks.append((track, artist))
    
tracks = pd.DataFrame(tracks, columns=['TrackID', 'ArtistID'])
assert type(tracks) is pd.DataFrame
tracks.head()
# Out:
#   TrackID ArtistID
# 0  166285    21533
# 1  166284    25289
# 2  166283    25289
# 3  166282    25289
# 4  166281    25289

# %%
for artist in tracks.ArtistID.unique():
    n_track = len(tracks[tracks['ArtistID'] == artist])
    print('Artist %s has published %d tracks' % (artist, n_track))
# Out:
# Artist 21533 has published 1 tracks
# Artist 25289 has published 6 tracks
# Artist 24811 has published 2 tracks
# Artist 22345 has published 9 tracks
# Artist 23208 has published 1 tracks
# Artist 6443 has published 1 tracks

# %%
tracks
# Out:
#    TrackID ArtistID
# 0   166285    21533
# 1   166284    25289
# 2   166283    25289
# 3   166282    25289
# 4   166281    25289
# 5   166280    25289
# 6   166279    25289
# 7   166262    24811
# 8   166261    24811
# 9   166271    22345
# 10  166270    22345
# 11  166269    22345
# 12  166268    22345
# 13  166267    22345
# 14  166266    22345
# 15  166265    22345
# 16  166264    22345
# 17  166263    22345
# 18  166260    23208
# 19  166259     6443
